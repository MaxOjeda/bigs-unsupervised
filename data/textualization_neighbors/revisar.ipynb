# %%
import pickle
import pandas as pd

# %%
with open("japan/original/gpt-4-1_clean.pkl", "rb") as f:
    data1 = pickle.load(f)

with open("japan/original/gpt-4-1_full.pkl", "rb") as f:
    data2 = pickle.load(f)

with open("japan/langchain/gpt-4-1.pkl", "rb") as f:
    data3 = pickle.load(f)

# %%
len(data1), len(data2), len(data3)
# Out:
# (435, 504, 435)

# %%
with open("../textualization/japan/original/gpt-4-1_clean.pkl", "rb") as f:
    data1 = pickle.load(f)

with open("../textualization/japan/original/gpt-4-1_full.pkl", "rb") as f:
    data2 = pickle.load(f)

with open("../textualization/japan/langchain/gpt-4-1.pkl", "rb") as f:
    data3 = pickle.load(f)

# %%
len(data1), len(data2), len(data3)
# Out:
# (435, 504, 548)
